# %% [markdown]
# #  UniRef Fasta Description
# > https://www.uniprot.org/help/fasta-headers
#
# ```bash
# >UniqueIdentifier ClusterName n=Members Tax=TaxonName TaxID=TaxonIdentifier RepID=RepresentativeMember
# ```
#
# Where:
#
# - **UniqueIdentifier** is the primary accession number of the UniRef cluster.
# - **ClusterName** is the name of the UniRef cluster.
# - **Members** is the number of UniRef cluster members.
# - **TaxonName** is the scientific name of the lowest common taxon shared by all UniRef cluster members.
# - **TaxonIdentifier** is the NCBI taxonomy identifier of the lowest common taxon shared by all UniRef cluster members.
# - **RepresentativeMember** is the entry name of the representative member of the UniRef cluster.

# %% [markdown]
# ### **Sample**
# ```bash
# >UniRef90_P0DPF3 Neuroblastoma breakpoint family member 9 n=4 Tax=Homo sapiens TaxID=9606 RepID=NBPF9_HUMAN
# >UniRef90_Q6P3W6 Neuroblastoma breakpoint family member 10 n=10 Tax=Homo sapiens TaxID=9606 RepID=NBPFA_HUMAN
# >UniRef90_Q86T75 Neuroblastoma breakpoint family member 11 n=8 Tax=Homo sapiens TaxID=9606 RepID=NBPFB_HUMAN
# >UniRef90_Q5TI25 Neuroblastoma breakpoint family member 14 n=4 Tax=Homo sapiens TaxID=9606 RepID=NBPFE_HUMAN
# ```

# %% [markdown]
# ### **UniRef90_P0DPF3** It's a cluster containing 4 members
#
# 1. **NBPF9_HUMAN**: Gene: NBPF9
# 2. **I1VE14_HUMAN**: Gene: NBPF10
# 3. **A0A075B764_HUMAN**: Gene:NBPF12
# 4. **UPI0003EAFEDB**: *unkown*: I BLASTed it against the whole uniprot and found 91.1% match with **GENE:NBPF14**
#
# ---
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. **UniRef90_P0DPF3:** {Gene:NBPF9}
# 2. **UniRef90_Q6P3W6:** {Gene:NBPF10}
# 3. **UniRef90_Q86T75:** {Gene:NBPF11}
# 4. **UniRef90_Q5TI25:** {Gene:NBPF14}

# %% [markdown]
# ---

# %% [markdown]
# ### **Other Examples**

# %% [markdown]
# ##### >UniRef90_Q3BBU5 NBPF (Fragment) n=3 Tax=Homo sapiens TaxID=9606 RepID=Q3BBU5_HUMAN
#
# - Gene: N/A
# - Description: NBPF (Fragment)
# - After running BLAST: Gene:NBPF19

# %% [markdown]
# ### **Other Examples**
# ##### >UniRef90_L8E7E2 Alternative protein NBPF9 n=1 Tax=Homo sapiens TaxID=9606 RepID=L8E7E2_HUMAN
# Gene: NBPF9
